# %% [markdown]
# # Strands Agent with AgentSkills Plugin on Amazon Bedrock AgentCore Runtime
#
# ## Overview
#
# This tutorial demonstrates how to build a Strands agent using the `AgentSkills` plugin for on-demand specialized instructions, run it locally, and deploy it to Amazon Bedrock AgentCore Runtime.
#
# The `AgentSkills` plugin supports two ways to define skills: **file-based** (a `SKILL.md` file with YAML frontmatter) and **programmatic** (a `Skill` object defined inline in Python). Both approaches can be mixed in the same agent.
#
# We will walk through two example skills — a **weather-reporter** skill defined as a file-based `SKILL.md`, and a **math-tutor** skill defined programmatically using the `Skill` class. We will first experiment locally, then deploy the agent to AgentCore Runtime.
#
# ### Tutorial Details
#
# | Field | Value |
# |---|---|
# | Tutorial type | Jupyter Notebook |
# | Agent type | Strands Agent with AgentSkills Plugin |
# | Agentic Framework | Strands Agents |
# | LLM model | Amazon Bedrock (Claude Haiku 4.5) |
# | Tutorial components | Skills (SKILL.md), AgentSkills Plugin, Local Experimentation, AgentCore Runtime Deployment |
# | Tutorial vertical | General / Developer Education |
# | Example complexity | Intermediate |
# | SDK used | bedrock-agentcore-starter-toolkit, strands-agents |
#
# ### Tutorial Architecture
#
# The agent uses the `AgentSkills` plugin which scans a `skills/` directory. Each skill is a `SKILL.md` file with YAML frontmatter (`name`, `description`, `allowed-tools`) and markdown instructions. The agent selects the appropriate skill based on the user's request.
#
# Two example skills are provided:
# - **weather-reporter**: Defined as a file-based `SKILL.md`. Paired with a custom `@tool` weather function, formats weather information with emoji, temperature ranges, and activity recommendations.
# - **math-tutor**: Defined programmatically using the `Skill` class (no file needed). Paired with the `calculator` tool from `strands-agents-tools`, solves math problems step-by-step showing all work.
#
# ### Tutorial Key Features
#
# * Two skill definition approaches: file-based (`SKILL.md`) and programmatic (`Skill` class)
# * Mixing file-based and programmatic skills in a single `AgentSkills` plugin
# * On-demand skill activation based on user intent
# * Local experimentation before cloud deployment
# * Seamless deployment to Amazon Bedrock AgentCore Runtime

# %% [markdown]
# ## Prerequisites
#
# To execute this tutorial you will need:
# * Python 3.10+
# * AWS credentials configured (`aws configure`)
# * Amazon Bedrock AgentCore SDK (`bedrock-agentcore`, `bedrock-agentcore-starter-toolkit`)
# * Strands Agents (`strands-agents`, `strands-agents-tools`)
# * Access to Amazon Bedrock models (Claude Haiku 4.5)
# * Docker or Finch (for AgentCore Runtime deployment)

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (1.50.2)
# Requirement already satisfied: strands-agents-tools in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.8.5)
# Collecting uv (from -r requirements.txt (line 3))
#   Using cached uv-0.12.0-py3-none-manylinux_2_28_aarch64.whl.metadata (11 kB)
# Requirement already satisfied: boto3 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (1.43.58)
# Collecting bedrock-agentcore<=0.1.5 (from -r requirements.txt (line 5))
#   Using cached bedrock_agentcore-0.1.5-py3-none-any.whl.metadata (7.0 kB)
# Collecting bedrock-agentcore-starter-toolkit==0.1.14 (from -r requirements.txt (line 6))
#   Using cached bedrock_agentcore_starter_toolkit-0.1.14-py3-none-any.whl.metadata (10.0 kB)
# Collecting autopep8>=2.3.2 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached autopep8-2.3.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: botocore>=1.40.35 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (1.43.58)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: httpx>=0.28.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.6 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (3.1.6)
# Collecting openapi-spec-validator>=0.7.2 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached openapi_spec_validator-0.9.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting prance>=25.4.8.0 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached prance-26.7.19.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.51 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (3.0.53)
# Collecting py-openapi-schema-to-json-schema>=0.0.3 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached py_openapi_schema_to_json_schema-0.0.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2.13.4)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (6.0.3)
# Collecting questionary>=2.1.0 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached questionary-2.1.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: requests>=2.25.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2.34.2)
# Requirement already satisfied: rich>=13.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (14.3.4)
# Collecting ruamel-yaml>=0.18.14 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Collecting toml>=0.10.2 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typer>=0.16.0 (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached typer-0.27.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (4.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: uvicorn>=0.34.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.51.0)
# Requirement already satisfied: starlette>=0.46.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from bedrock-agentcore<=0.1.5->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.44.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.65b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.44.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from boto3->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from boto3->-r requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from botocore>=1.40.35->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: anyio in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (4.14.2)
# Requirement already satisfied: certifi in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: idna in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.28.1->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2026.6.3)
# Requirement already satisfied: httpx-sse>=0.4 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.14.2)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.0.32)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.4.6)
# Requirement already satisfied: opentelemetry-instrumentation==0.65b0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.65b0)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.65b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.65b0)
# Requirement already satisfied: packaging>=18.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.65b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (26.2)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.40.35->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.14.3)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.3)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (12.3.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.30.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.24.5)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.9.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from prompt-toolkit>=3.0.51->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.8.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from requests>=2.25.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (3.4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from rich>=13.0.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from rich>=13.0.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Collecting pycodestyle>=2.12.0 (from autopep8>=2.3.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached pycodestyle-2.14.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from jinja2>=3.1.6->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.1.2)
# Collecting jsonschema-path<0.6.0,>=0.5.0 (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached jsonschema_path-0.5.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting lazy-object-proxy<2.0,>=1.7.1 (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Downloading lazy_object_proxy-1.12.0-cp313-cp313-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (5.1 kB)
# Collecting openapi-schema-validator<0.10.0,>=0.9.0 (from openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached openapi_schema_validator-0.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting pathable<0.7.0,>=0.6.0 (from jsonschema-path<0.6.0,>=0.5.0->openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached pathable-0.6.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: rfc3339-validator in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from openapi-schema-validator<0.10.0,>=0.9.0->openapi-spec-validator>=0.7.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.2.2)
# Collecting chardet>=5.2 (from prance>=25.4.8.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Downloading chardet-7.4.3-cp313-cp313-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl.metadata (9.4 kB)
# Requirement already satisfied: cryptography>=3.4.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: pycparser in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.0)
# Collecting shellingham>=1.3.0 (from typer>=0.16.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from typer>=0.16.0->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (0.0.5)
# Requirement already satisfied: click>=7.0 in /home/ubuntu/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages (from uvicorn>=0.34.2->bedrock-agentcore-starter-toolkit==0.1.14->-r requirements.txt (line 6)) (8.4.2)
# Using cached bedrock_agentcore_starter_toolkit-0.1.14-py3-none-any.whl (163 kB)
# Using cached bedrock_agentcore-0.1.5-py3-none-any.whl (62 kB)
# Using cached uv-0.12.0-py3-none-manylinux_2_28_aarch64.whl (21.0 MB)
# Using cached autopep8-2.3.2-py2.py3-none-any.whl (45 kB)
# Using cached openapi_spec_validator-0.9.0-py3-none-any.whl (50 kB)
# Using cached jsonschema_path-0.5.0-py3-none-any.whl (24 kB)
# Downloading lazy_object_proxy-1.12.0-cp313-cp313-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (71 kB)
# Using cached openapi_schema_validator-0.9.0-py3-none-any.whl (19 kB)
# Using cached pathable-0.6.0-py3-none-any.whl (18 kB)
# Using cached prance-26.7.19.0-py3-none-any.whl (2.8 MB)
# Downloading chardet-7.4.3-cp313-cp313-manylinux2014_aarch64.manylinux_2_17_aarch64.manylinux_2_28_aarch64.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.0/874.0 kB 50.8 MB/s  0:00:00
# Using cached py_openapi_schema_to_json_schema-0.0.3-py3-none-any.whl (7.0 kB)
# Using cached pycodestyle-2.14.0-py2.py3-none-any.whl (31 kB)
# Using cached questionary-2.1.1-py3-none-any.whl (36 kB)
# Using cached ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached typer-0.27.0-py3-none-any.whl (122 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: py-openapi-schema-to-json-schema, uv, toml, shellingham, ruamel-yaml, pycodestyle, pathable, lazy-object-proxy, chardet, questionary, prance, jsonschema-path, autopep8, typer, openapi-schema-validator, openapi-spec-validator, bedrock-agentcore, bedrock-agentcore-starter-toolkit
#   Attempting uninstall: bedrock-agentcore╺━━━━━━━━━━━━━━━ 11/18 [jsonschema-path]
#     Found existing installation: bedrock-agentcore 1.19.0━━━━━ 11/18 [jsonschema-path]
#     Uninstalling bedrock-agentcore-1.19.0:━╸━━━━ 16/18 [bedrock-agentcore]
#       Successfully uninstalled bedrock-agentcore-1.19.090m━━━━ 16/18 [bedrock-agentcore]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [bedrock-agentcore-starter-toolkit]re]
# Successfully installed autopep8-2.3.2 bedrock-agentcore-0.1.5 bedrock-agentcore-starter-toolkit-0.1.14 chardet-7.4.3 jsonschema-path-0.5.0 lazy-object-proxy-1.12.0 openapi-schema-validator-0.9.0 openapi-spec-validator-0.9.0 pathable-0.6.0 prance-26.7.19.0 py-openapi-schema-to-json-schema-0.0.3 pycodestyle-2.14.0 questionary-2.1.1 ruamel-yaml-0.19.1 shellingham-1.5.4 toml-0.10.2 typer-0.27.0 uv-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Skill Creation Approaches
#
# The `AgentSkills` plugin supports two ways to define skills. This tutorial demonstrates both.
#
# ### Approach 1: File-based skill (SKILL.md)
#
# A file-based skill is a directory containing a `SKILL.md` file with YAML frontmatter and a markdown instruction body. This approach is ideal for skills you want to version-control, share across projects, or edit without touching Python code.
#
# ```
# skills/
# └── weather-reporter/
#     └── SKILL.md
# ```
#
# **SKILL.md format:**
# ```markdown
# ---
# name: skill-name
# description: Short description used by the agent to decide when to activate this skill
# allowed-tools:
#   - tool_name
# ---
#
# # Skill Instructions
#
# Markdown body with behavioral instructions for the agent.
# ```
#
# The YAML frontmatter fields:
# - `name`: Unique identifier for the skill (kebab-case)
# - `description`: Human-readable description used by the agent to decide when to activate the skill
# - `allowed-tools`: List of tool names the skill is permitted to use

# %%
import os

os.makedirs("skills/weather-reporter", exist_ok=True)

# %%
# %%writefile skills/weather-reporter/SKILL.md
# ---
# name: weather-reporter
# description: Format weather information with emoji, temperature ranges, and activity recommendations
# allowed-tools:
#   - weather
# ---
#
# # Weather Reporter Instructions
#
# You are a friendly weather reporter. When presenting weather information:
#
# 1. **Use weather emoji** to make the report visually engaging:
#    - ☀️ for sunny/clear conditions
#    - 🌧️ for rain
#    - ⛅ for partly cloudy
#    - 🌩️ for thunderstorms
#    - ❄️ for snow
#    - 🌫️ for fog/mist
#
# 2. **Include temperature ranges** in both Fahrenheit and Celsius
#
# 3. **Provide activity recommendations** based on the conditions:
#    - Suggest outdoor activities for good weather
#    - Recommend indoor alternatives for bad weather
#    - Include clothing suggestions (e.g., "bring an umbrella", "wear a light jacket")
#
# 4. **Format your response** as a friendly weather report with clear sections for current conditions and recommendations.

# %% [markdown]
# ### Approach 2: Programmatic skill (Skill class)
#
# A programmatic skill is defined inline in Python using the `Skill` class — no directory or file needed. This is convenient for simple skills, dynamic skill generation, or when you want to keep everything in one script.
#
# ```python
# from strands import Skill
#
# math_tutor = Skill(
#     name="math-tutor",
#     description="Solve math problems step-by-step, showing all work",
#     instructions="Break down math problems into clear steps. Show all intermediate calculations and explain your reasoning at each step.",
# )
# ```
#
# Both skill types are passed to `AgentSkills` in the same `skills` list — you can freely mix file-based and programmatic skills:
#
# ```python
# from strands import AgentSkills
#
# plugin = AgentSkills(skills=["./skills/weather-reporter", math_tutor])
# ```
#
# The `math-tutor` skill will be defined programmatically in the agent script below.

# %% [markdown]
# ## Local Agent Experimentation
#
# Before deploying to AgentCore Runtime, we'll run the agent locally to verify that the skills work as expected.
#
# The agent uses `BedrockModel` with Claude Haiku 4.5 and loads skills from the `skills/` directory via the `AgentSkills` plugin. Running locally lets you iterate quickly on skill definitions and agent behavior without a full deployment cycle.

# %% [markdown]
# ## Deploying to Amazon Bedrock AgentCore Runtime
#
# Now that we've verified the agent works locally, we'll deploy it to Amazon Bedrock AgentCore Runtime. The deployment version of the agent script wraps the same logic with `BedrockAgentCoreApp`, which exposes `/invocations` and `/ping` HTTP endpoints.
#
# The `bedrock-agentcore-starter-toolkit` packages the agent script, the `skills/` directory, and all dependencies into a Docker container, pushes it to Amazon ECR, and creates the AgentCore Runtime endpoint automatically.
#
# > **Note:** Make sure Docker or Finch is running before proceeding with deployment.

# %%
import os
import boto3

AWS_PROFILE = "default"
REGION = "ap-northeast-2"

os.environ["AWS_PROFILE"] = AWS_PROFILE
os.environ["AWS_DEFAULT_REGION"] = REGION

# Force boto3 to use the new profile by resetting the default session
boto3.setup_default_session(profile_name=AWS_PROFILE, region_name=REGION)

# Verify credentials are valid
identity = boto3.client("sts").get_caller_identity()
print(f"Account: {identity['Account']}, Region: {REGION}")
# Out:
# Account: 813307607383, Region: ap-northeast-2

# %%
# %%writefile agent_with_skills.py
from strands import Agent, tool, AgentSkills, Skill
from strands_tools import calculator
from strands.models import BedrockModel
from bedrock_agentcore.runtime import BedrockAgentCoreApp

@tool
def weather() -> dict:
    """Get current weather information."""
    return {
        "condition": "sunny",
        "temp_f": 75,
        "temp_c": 24,
        "humidity": 45,
        "wind_mph": 10
    }

# Programmatic skill — defined inline, no SKILL.md file needed
math_tutor = Skill(
    name="math-tutor",
    description="Solve math problems step-by-step, showing all work and explaining reasoning",
    instructions=(
        "You are a patient and thorough math tutor. When solving math problems:\n"
        "1. Break down the problem into clear, numbered steps.\n"
        "2. Show all intermediate calculations — never skip steps.\n"
        "3. Explain your reasoning at each step, identifying the mathematical concept applied.\n"
        "4. Use the calculator tool for arithmetic to ensure accuracy.\n"
        "5. Verify your answer against the original problem.\n"
        "6. Summarize with a clear final answer."
    ),
)

model = BedrockModel(model_id="global.anthropic.claude-haiku-4-5-20251001-v1:0")
# Mix file-based skill (weather-reporter) with programmatic skill (math_tutor)
skills = AgentSkills(skills=["./skills/weather-reporter", math_tutor])
agent = Agent(model=model, tools=[calculator, weather], plugins=[skills])

app = BedrockAgentCoreApp()

@app.entrypoint
def invoke_agent(payload: dict) -> str:
    response = agent(payload.get("prompt", ""))
    return response.message['content'][0]['text']

if __name__ == "__main__":
    app.run()
# Out:
# Overwriting agent_with_skills.py

# %% [markdown]
# ## Configure and Launch the AgentCore Runtime
#
# Use the `Runtime` class from `bedrock-agentcore-starter-toolkit` to configure the deployment. Setting `auto_create_execution_role=True` and `auto_create_ecr=True` lets the toolkit create the required IAM role and ECR repository automatically.
#
# The `launch()` call builds the Docker image, pushes it to ECR, and creates the AgentCore Runtime endpoint. This may take a few minutes.

# %%
import boto3
from bedrock_agentcore_starter_toolkit import Runtime

agentcore_runtime = Runtime()
agentcore_runtime.configure(
    entrypoint="agent_with_skills.py",
    auto_create_execution_role=True,
    auto_create_ecr=True,
    requirements_file="requirements.txt",
    agent_name="strands_skills_tutorial",
    region=REGION,
)
print("Configuration complete.")
# Out:
# Entrypoint parsed: file=/home/ubuntu/dev/github/puny/agentcore-samples/06-workshops/01-AgentCore-runtime/01-hosting-agent/06-strands-with-skills/agent_with_skills.py, bedrock_agentcore_name=agent_with_skills
# Configuring BedrockAgentCore agent: strands_skills_tutorial
# Generated Dockerfile: /home/ubuntu/dev/github/puny/agentcore-samples/06-workshops/01-AgentCore-runtime/01-hosting-agent/06-strands-with-skills/Dockerfile
# Generated .dockerignore: /home/ubuntu/dev/github/puny/agentcore-samples/06-workshops/01-AgentCore-runtime/01-hosting-agent/06-strands-with-skills/.dockerignore
# Keeping 'strands_skills_tutorial' as default agent
# Bedrock AgentCore configured: /home/ubuntu/dev/github/puny/agentcore-samples/06-workshops/01-AgentCore-runtime/01-hosting-agent/06-strands-with-skills/.bedrock_agentcore.yaml
# Configuration complete.

# %%
launch_result = agentcore_runtime.launch()
print("Launch initiated. Waiting for runtime to become READY...")
# Out:
# 🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
#    • Build ARM64 containers in the cloud with CodeBuild
#    • No local Docker required
# 💡 Available deployment modes:
#    • runtime.launch()                           → CodeBuild (current)
#    • runtime.launch(local=True)                 → Local development
#    • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# Starting CodeBuild ARM64 deployment for agent 'strands_skills_tutorial' to account 813307607383 (ap-northeast-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Using ECR repository from config: 813307607383.dkr.ecr.ap-northeast-2.amazonaws.com/bedrock-agentcore-strands_skills_tutorial
# Using execution role from config: arn:aws:iam::813307607383:role/AmazonBedrockAgentCoreSDKRuntime-ap-northeast-2-6495ca7eb3
# Preparing CodeBuild project and uploading source...
# Using CodeBuild role from config: arn:aws:iam::813307607383:role/AmazonBedrockAgentCoreSDKCodeBuild-ap-northeast-2-6495ca7eb3
# Using .dockerignore with 44 patterns
# Uploaded source to S3: strands_skills_tutorial/source.zip
# Using CodeBuild project from config: bedrock-agentcore-strands_skills_tutorial-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.0s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 7.3s
# 🔄 DOWNLOAD_SOURCE started (total: 8s)
# ✅ DOWNLOAD_SOURCE completed in 1.0s
# 🔄 BUILD started (total: 9s)
# ✅ BUILD completed in 19.8s
# 🔄 POST_BUILD started (total: 29s)
# ✅ POST_BUILD completed in 11.4s
# 🔄 COMPLETED started (total: 41s)
# ✅ COMPLETED completed in 1.0s
# 🎉 CodeBuild completed successfully in 0m 41s
# CodeBuild completed successfully
# ✅ CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# Failed to update agent ID 'strands_skills_tutorial-FTF3T42JNW': An error occurred (ResourceNotFoundException) when calling the UpdateAgentRuntime operation: Agent 'strands_skills_tutorial-FTF3T42JNW' was not found. Please check the agent ID and try again.
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 launch_result = agentcore_runtime.launch()
#       2 print("Launch initiated. Waiting for runtime to become READY...")
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/notebook/runtime/bedrock_agentcore.py:191, in Runtime.launch(self, local, local_build, auto_update_on_conflict, env_vars)
#     188 use_codebuild = not (local or local_build)
#     190 try:
# --> 191     result = launch_bedrock_agentcore(
#     192         self._config_path,
#     193         local=local,
#     194         use_codebuild=use_codebuild,
#     195         auto_update_on_conflict=auto_update_on_conflict,
#     196         env_vars=env_vars,
#     197     )
#     198 except RuntimeError as e:
#     199     # Enhance Docker-related error messages
#     200     error_msg = str(e)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/operations/runtime/launch.py:282, in launch_bedrock_agentcore(config_path, agent_name, local, use_codebuild, env_vars, auto_update_on_conflict)
#     280 # Handle CodeBuild deployment (but not for local mode)
#     281 if use_codebuild and not local:
# --> 282     return _launch_with_codebuild(
#     283         config_path=config_path,
#     284         agent_name=agent_config.name,
#     285         agent_config=agent_config,
#     286         project_config=project_config,
#     287         auto_update_on_conflict=auto_update_on_conflict,
#     288         env_vars=env_vars,
#     289     )
#     291 # Log which agent is being launched
#     292 mode = "locally" if local else "to cloud"
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/operations/runtime/launch.py:506, in _launch_with_codebuild(config_path, agent_name, agent_config, project_config, auto_update_on_conflict, env_vars)
#     495 build_id, ecr_uri, region, account_id = _execute_codebuild_workflow(
#     496     config_path=config_path,
#     497     agent_name=agent_name,
#    (...)    502     env_vars=env_vars,
#     503 )
#     505 # Deploy to Bedrock AgentCore
# --> 506 agent_id, agent_arn = _deploy_to_bedrock_agentcore(
#     507     agent_config,
#     508     project_config,
#     509     config_path,
#     510     agent_name,
#     511     ecr_uri,
#     512     region,
#     513     account_id,
#     514     env_vars=env_vars,
#     515     auto_update_on_conflict=auto_update_on_conflict,
#     516 )
#     518 log.info("Deployment completed successfully - Agent: %s", agent_arn)
#     520 return LaunchResult(
#     521     mode="codebuild",
#     522     tag=f"bedrock_agentcore-{agent_name}:latest",
#    (...)    526     agent_id=agent_id,
#     527 )
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/operations/runtime/launch.py:200, in _deploy_to_bedrock_agentcore(agent_config, project_config, config_path, agent_name, ecr_uri, region, account_id, env_vars, auto_update_on_conflict)
#     194     if is_role_validation_error:
#     195         log.error(
#     196             "Role validation failed after %d attempts. The execution role may not be ready. Role: %s",
#     197             max_retries + 1,
#     198             agent_config.aws.execution_role,
#     199         )
# --> 200     raise e
#     202 # Calculate delay with exponential backoff
#     203 delay = min(base_delay * (2**attempt), max_delay)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/operations/runtime/launch.py:167, in _deploy_to_bedrock_agentcore(agent_config, project_config, config_path, agent_name, ecr_uri, region, account_id, env_vars, auto_update_on_conflict)
#     165 for attempt in range(max_retries + 1):
#     166     try:
# --> 167         agent_info = bedrock_agentcore_client.create_or_update_agent(
#     168             agent_id=agent_config.bedrock_agentcore.agent_id,
#     169             agent_name=agent_name,
#     170             image_uri=f"{ecr_uri}:latest",
#     171             execution_role_arn=agent_config.aws.execution_role,
#     172             network_config=network_config,
#     173             authorizer_config=agent_config.get_authorizer_configuration(),
#     174             request_header_config=agent_config.request_header_configuration,
#     175             protocol_config=protocol_config,
#     176             env_vars=env_vars,
#     177             auto_update_on_conflict=auto_update_on_conflict,
#     178         )
#     179         break  # Success! Exit retry loop
#     181     except ClientError as e:
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/services/runtime.py:316, in BedrockAgentCoreClient.create_or_update_agent(self, agent_id, agent_name, image_uri, execution_role_arn, network_config, authorizer_config, request_header_config, protocol_config, env_vars, auto_update_on_conflict)
#     314 """Create or update agent."""
#     315 if agent_id:
# --> 316     return self.update_agent(
#     317         agent_id,
#     318         image_uri,
#     319         execution_role_arn,
#     320         network_config,
#     321         authorizer_config,
#     322         request_header_config,
#     323         protocol_config,
#     324         env_vars,
#     325     )
#     326 return self.create_agent(
#     327     agent_name,
#     328     image_uri,
#    (...)    335     auto_update_on_conflict,
#     336 )
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/services/runtime.py:253, in BedrockAgentCoreClient.update_agent(self, agent_id, image_uri, execution_role_arn, network_config, authorizer_config, request_header_config, protocol_config, env_vars)
#     250 if env_vars is not None:
#     251     params["environmentVariables"] = env_vars
# --> 253 resp = self.client.update_agent_runtime(**params)
#     254 agent_arn = resp["agentRuntimeArn"]
#     255 self.logger.info("Successfully updated agent ID '%s', ARN: %s", agent_id, agent_arn)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/botocore/client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/botocore/client.py:1094, in BaseClient._make_api_call(self, operation_name, api_params)
#    1090     error_code = request_context.get(
#    1091         'error_code_override'
#    1092     ) or error_info.get("Code")
#    1093     error_class = self.exceptions.from_code(error_code)
# -> 1094     raise error_class(parsed_response, operation_name)
#    1095 else:
#    1096     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the UpdateAgentRuntime operation: Agent 'strands_skills_tutorial-FTF3T42JNW' was not found. Please check the agent ID and try again.

# %%
import time

terminal_states = ["READY", "CREATE_FAILED", "UPDATE_FAILED", "DELETE_FAILED"]

status_response = agentcore_runtime.status()
current_status = status_response.endpoint["status"]
print(f"Status: {current_status}")

while current_status not in terminal_states:
    time.sleep(30)
    status_response = agentcore_runtime.status()
    current_status = status_response.endpoint["status"]
    print(f"Status: {current_status}")

if current_status == "READY":
    print("Runtime is READY. Proceeding to invocation.")
else:
    print(f"Deployment ended with status: {current_status}. Check CloudWatch logs for details.")
# Out:
# Retrieved Bedrock AgentCore status for: strands_skills_tutorial
# Status: READY
# Runtime is READY. Proceeding to invocation.

# %% [markdown]
# ## Test Weather Skill

# %%
# Invoke the deployed runtime with a prompt that triggers skill activation
invoke_payload = {
    "prompt": "What's the weather like today? Give me a full report with emoji and activity recommendations."
}
response = agentcore_runtime.invoke(invoke_payload)
response_text = "".join(response["response"])
print(response_text)
# Out:
# "I see the weather data returned ranges rather than specific values. Let me provide you with a general report based on the conditions:\n\n## 🌤️ Today's Weather Report\n\n**Current Condition:** ☀️ **Sunny**\n\n**Temperature Range:** \n- 🌡️ Fahrenheit: 1°F to 99°F\n- 🌡️ Celsius: -17°C to 56°C\n\n**Humidity Range:** 0% to 101%\n\n**Wind Speed Range:** 0 to 50 mph\n\n---\n\n## 📋 Activity Recommendations:\n\nSince we have a sunny day ahead, here are some great outdoor activities:\n\n### ✅ Perfect For:\n- 🚴 **Cycling or biking** - Great visibility with sunny skies\n- 🥾 **Hiking** - Sunny weather makes trails more enjoyable\n- ⚽ **Sports activities** - Perfect for outdoor games\n- 🎣 **Fishing** - Sunny conditions are ideal\n- 📸 **Photography** - Excellent natural lighting\n- 🏞️ **Picnics** - Enjoy nature in the sunshine\n- 🏃 **Running/jogging** - Great outdoor exercise opportunity\n- 🧗 **Rock climbing or outdoor adventures**\n\n### 💡 Tips:\n- ☀️ Apply sunscreen (SPF 30+) before heading out\n- 💧 Stay hydrated - bring plenty of water\n- 👒 Wear a hat or sunglasses for comfort\n- 👕 Wear light, breathable clothing\n- 🌳 Take breaks in shaded areas if needed\n\nThe sunny weather is ideal for outdoor activities - make the most of it! ✨"

# %%
from IPython.display import Markdown, display

# Extract and display the response text
response_text = "".join(response["response"])
# Strip surrounding quotes and replace escaped newlines
response_text = response_text.strip('"').replace("\\n", "\n")
display(Markdown(response_text))

# %% [markdown]
# ## Test Math Skill

# %%
# Invoke the deployed runtime with a prompt that triggers skill activation
invoke_payload = {"prompt": "help me solve 23+458*89"}
response = agentcore_runtime.invoke(invoke_payload)
response_text = "".join(response["response"])
print(response_text)
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Invoke the deployed runtime with a prompt that triggers skill activation
#       2 invoke_payload = {"prompt": "help me solve 23+458*89"}
# ----> 3 response = agentcore_runtime.invoke(invoke_payload)
#       4 response_text = "".join(response["response"])
#       5 print(response_text)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/notebook/runtime/bedrock_agentcore.py:280, in Runtime.invoke(self, payload, session_id, bearer_token, local, user_id)
#     277     log.info("  runtime.invoke({'message': 'Hello'})")
#     278     raise ValueError("Must configure and launch first.")
# --> 280 result = invoke_bedrock_agentcore(
#     281     config_path=self._config_path,
#     282     payload=payload,
#     283     session_id=session_id,
#     284     bearer_token=bearer_token,
#     285     local_mode=local,
#     286     user_id=user_id,
#     287 )
#     288 return result.response
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/operations/runtime/invoke.py:97, in invoke_bedrock_agentcore(config_path, payload, agent_name, session_id, bearer_token, user_id, local_mode, custom_headers)
#      94     else:
#      95         # Use existing boto3 client
#      96         bedrock_agentcore_client = BedrockAgentCoreClient(region)
# ---> 97         response = bedrock_agentcore_client.invoke_endpoint(
#      98             agent_arn=agent_arn,
#      99             payload=payload_str,
#     100             session_id=session_id,
#     101             user_id=user_id,
#     102             custom_headers=custom_headers,
#     103         )
#     105 return InvokeResult(
#     106     response=response,
#     107     session_id=session_id,
#     108     agent_arn=agent_arn,
#     109 )
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/bedrock_agentcore_starter_toolkit/services/runtime.py:475, in BedrockAgentCoreClient.invoke_endpoint(self, agent_arn, payload, session_id, endpoint_name, user_id, custom_headers)
#     470     handler_id = self.dataplane_client.meta.events.register_first(
#     471         "before-sign.bedrock-agentcore.InvokeAgentRuntime", add_all_headers
#     472     )
#     474 try:
# --> 475     response = self.dataplane_client.invoke_agent_runtime(**req)
#     476     return _handle_aws_response(response)
#     477 finally:
#     478     # Always clean up event handler
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/botocore/client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/dev/github/puny/agentcore-samples/.venv/lib/python3.13/site-packages/botocore/client.py:1094, in BaseClient._make_api_call(self, operation_name, api_params)
#    1090     error_code = request_context.get(
#    1091         'error_code_override'
#    1092     ) or error_info.get("Code")
#    1093     error_class = self.exceptions.from_code(error_code)
# -> 1094     raise error_class(parsed_response, operation_name)
#    1095 else:
#    1096     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the InvokeAgentRuntime operation: No endpoint or agent found with qualifier 'DEFAULT' for agent 'arn:aws:bedrock-agentcore:ap-northeast-2:813307607383:runtime/strands_skills_tutorial-FTF3T42JNW'

# %% [markdown]
# ## Cleanup
#
# Let's now clean up the AgentCore Runtime and associated resources. We delete the runtime first to avoid undesired costs, then clean up supporting resources like the ECR repository.

# %%
import boto3

agent_name = "strands_skills_tutorial"

agentcore_control_client = boto3.client("bedrock-agentcore-control", region_name=REGION)

# Look up agent_id by name in case this cell runs independently
runtimes = agentcore_control_client.list_agent_runtimes()
agent_id = next(
    (r["agentRuntimeId"] for r in runtimes["agentRuntimes"] if r["agentRuntimeName"] == agent_name),
    None,
)

if not agent_id:
    print(f"⚠️ No runtime found with name '{agent_name}'")
else:
    # Delete the AgentCore Runtime
    try:
        agentcore_control_client.delete_agent_runtime(agentRuntimeId=agent_id)
        print(f"✅ Runtime '{agent_name}' ({agent_id}) deleted")
    except Exception as e:
        print(f"⚠️ Failed to delete runtime: {e}")
# Out:
# ⚠️ No runtime found with name 'strands_skills_tutorial'

# %%
ecr_client = boto3.client("ecr", region_name=REGION)
REPO_NAME = "bedrock-agentcore-strands_skills_tutorial"
# REPO_NAME = launch_result.ecr_uri.split('/')[1]

# Delete the ECR repository created during deployment
try:
    ecr_client.delete_repository(repositoryName=REPO_NAME, force=True)
    print(f"✅ ECR repository '{REPO_NAME}' deleted")
except Exception as e:
    print(f"⚠️ Failed to delete ECR repository: {e}")
